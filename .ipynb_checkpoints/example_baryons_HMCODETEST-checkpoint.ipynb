# %%
import numpy as np
import time
import matplotlib
from matplotlib import pyplot as plt
import os

import sys
sys.path.append('axionCAMB_and_lin_PS/')
sys.path.append('cosmology/')
sys.path.append('axion_functions/')
sys.path.append('halo_model/')

from axionCAMB_and_lin_PS import axionCAMB_wrapper 
from axionCAMB_and_lin_PS import load_cosmology  
from axionCAMB_and_lin_PS import lin_power_spectrum 
from axionCAMB_and_lin_PS import PS_interpolate 

from halo_model import HMcode_params
from halo_model import PS_nonlin_cold
from halo_model import PS_nonlin_axion
from halo_model import baryons

from axion_functions import axion_params

# %%
### Baryons with no axions

start = time.time()

################################################################################
# Set-up experiment parameters
################################################################################

input_file_path = '/Users/cp2091/PhD/KR_ULADM/axionHMcode_Tagn/input_files/input_file.txt'
input_file_path_baryon = '/Users/cp2091/PhD/KR_ULADM/axionHMcode_Tagn/input_files/input_file_AXION_BARYON.txt'

try:
    f = open(input_file_path)
except IOError:
    print("Input file not accessible, pleas check the file path")
finally:
    f.close()
axionCAMB_exe_path = '/Users/cp2091/PhD/KR_ULADM/axionCAMB'
if os.path.exists(axionCAMB_exe_path+'/./camb') == False:
    print("executabel axionCAMB is not in the given directory, pleas check the path")

# %%
################################################################################    
# save cosmological parameter in a dictionary 
################################################################################

cosmos_AXION_BARYON = load_cosmology.load_cosmology_input(input_file_path_baryon) 
cosmos_LCDM = load_cosmology.load_LCDM_cosmology_input(input_file_path)

# Check here later for why LCDM not working

################################################################################
# Run axionCAMB on mixed and LCDM cosmology 
################################################################################

print("axionCAMB is running. Computes transfer function for a LCDM cosmology")
axionCAMB_wrapper.axioncamb_params('paramfiles/paramfile_axionCAMB_LCDM.txt', 
                                   cosmos_LCDM, output_root='paramfiles/cosmos_LCDM', print_info = True)
axionCAMB_wrapper.run_axioncamb('paramfiles/paramfile_axionCAMB_LCDM.txt', 
                                axionCAMB_exe_path,
                                cosmos_LCDM, print_info = True)

print("axionCAMB is running. Computes transfer function for a same cosmology but now with baryons cosmology")
axionCAMB_wrapper.axioncamb_params('paramfiles/paramfile_axionCAMB_AXION_BARYON.txt', 
                                   cosmos_AXION_BARYON, output_root='paramfiles/cosmos_AXION_BARYON', print_info = False)
axionCAMB_wrapper.run_axioncamb('paramfiles/paramfile_axionCAMB_AXION_BARYON.txt', 
                                axionCAMB_exe_path,
                                cosmos_AXION_BARYON, print_info = False)
# Out:
# axionCAMB is running. Computes transfer function for a LCDM cosmology
# Writing axionCAMB parameters to paramfiles/paramfile_axionCAMB_LCDM.txt
# Running CAMB on /Users/cp2091/PhD/KR_ULADM/axionHMcode_Tagn/paramfiles/paramfile_axionCAMB_LCDM.txt
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG
# axionCAMB is running. Computes transfer function for a same cosmology but now with baryons cosmology
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_UNDERFLOW_FLAG

# %%
################################################################################
# Create linear power spectra from axionCAMB tranfer functions 
################################################################################
# lin PS on given k range

power_spec_dic_LCDM = lin_power_spectrum.func_power_spec_dic('paramfiles/cosmos_LCDM_transfer_out.dat', cosmos_LCDM)
power_spec_dic_AXION_BARYON = lin_power_spectrum.func_power_spec_dic('paramfiles/cosmos_AXION_BARYON_transfer_out.dat', cosmos_AXION_BARYON)

#interpolated lin PS for the correct computations of the variance

power_spec_interp_dic_LCDM = lin_power_spectrum.func_power_spec_interp_dic(power_spec_dic_LCDM, cosmos_LCDM)
power_spec_interp_dic_ax_AXION_BARYON = lin_power_spectrum.func_power_spec_interp_dic(power_spec_dic_AXION_BARYON, cosmos_AXION_BARYON)

##################################
##############################################
# Compute parameter related to axions and HMCode2020
################################################################################
print('-' * 50)
M_arr = np.logspace(cosmos_LCDM['M_min'], cosmos_LCDM['M_max'], 100)
print("Calculate axion quantities; cut-off mass, central density scale of axion density profile and axion halo mass.")
print(cosmos_LCDM['M_min'], cosmos_LCDM['M_max'])
axion_param_AXION_BARYON = axion_params.func_axion_param_dic(M_arr, cosmos_AXION_BARYON, power_spec_interp_dic_ax_AXION_BARYON, eta_given=False)

print("Create dictionary with parameters of HMCode2020")

hmcode_params_LCDM = HMcode_params.HMCode_param_dic(cosmos_LCDM, power_spec_interp_dic_LCDM['k'], power_spec_interp_dic_LCDM['cold'])
hmcode_params_AXION_BARYON = HMcode_params.HMCode_param_dic(cosmos_AXION_BARYON, power_spec_interp_dic_ax_AXION_BARYON['k'], power_spec_interp_dic_ax_AXION_BARYON['cold'])

print("computation time upto here: {:.0f} s".format(time.time() -start))
# Out:
# --------------------------------------------------
# Calculate axion quantities; cut-off mass, central density scale of axion density profile and axion halo mass.
# 7 18
# Create dictionary with parameters of HMCode2020
# computation time upto here: 22 s

# %%
import importlib
importlib.reload(baryons)
# Out:
# <module 'halo_model.baryons' from '/Users/cp2091/PhD/KR_ULADM/axionHMcode_Tagn/halo_model/baryons.py'>

# %%
################################################################################
# Caluclate non-linear power spectrum in LCDM cosmology both DM only and with baryons
################################################################################
#print(power_spec_dic_LCDM)
#print('Caluclate non-linear power spectrum in LCDM cosmology with the halo model')
PS_LCDM_matter_nonlin = PS_nonlin_cold.func_non_lin_PS_matter(M_arr, power_spec_dic_LCDM['k'], power_spec_dic_LCDM['power_total'], power_spec_interp_dic_LCDM['k'], power_spec_interp_dic_LCDM['cold'], cosmos_LCDM, hmcode_params_LCDM, cosmos_LCDM['Omega_m_0'], cosmos_LCDM['Omega_db_0'],  alpha = False, eta_given = False, one_halo_damping = True, two_halo_damping = False, Tagn=None)
print(PS_LCDM_matter_nonlin)
#print('Caluclate non-linear power spectrum in LCDM cosmology with the halo model - now including baryons via Tagn parameter')
#T_agn = np.power(10, 7.6)
#PS_LCDM_matter_nonlin_baryons = PS_nonlin_cold.func_non_lin_PS_matter(M_arr, power_spec_dic_LCDM['k'], power_spec_dic_LCDM['power_total'], power_spec_interp_dic_LCDM['k'], power_spec_interp_dic_LCDM['cold'], cosmos_LCDM, hmcode_params_LCDM, cosmos_LCDM['Omega_m_0'], cosmos_LCDM['Omega_db_0'],  alpha = False, eta_given = False, one_halo_damping = False, two_halo_damping = False, Tagn=T_agn)
################################################################################
# Save both power spectra in files
################################################################################

#print("Save the non-linear power spectra in a file in the folowing order:")
#print("k [h/Mpc], non-lin total matter PS in LCDM [(Mpc/h)^3] and non-lin total matter PS with baryons in LCDM [(Mpc/h)^3]")

datafile_path = "output/nonlin_PS_CDMO_CDMBARYONS.txt" #change path if you want
#np.savetxt(datafile_path , data_ax)
# Out:
# (array([3.18276680e+02, 5.15494764e+02, 8.34603417e+02, 1.34984148e+03,
#        2.17754405e+03, 3.49271721e+03, 5.53883348e+03, 8.59903457e+03,
#        1.28597031e+04, 1.41004126e+04, 1.53944317e+04, 1.67260038e+04,
#        1.80737870e+04, 1.94105835e+04, 2.07020641e+04, 2.19059816e+04,
#        2.29734172e+04, 2.38464260e+04, 2.44627288e+04, 2.47555315e+04,
#        2.46618413e+04, 2.41318909e+04, 2.31426444e+04, 2.17128099e+04,
#        1.99218313e+04, 1.79155006e+04, 1.61073853e+04, 1.42819019e+04,
#        1.26880371e+04, 1.16565868e+04, 1.07730311e+04, 9.85076905e+03,
#        8.84970941e+03, 7.71359283e+03, 6.66158206e+03, 5.84752147e+03,
#        5.29997054e+03, 4.95532795e+03, 4.71085970e+03, 4.46450994e+03,
#        4.15887217e+03, 3.80055396e+03, 3.43732530e+03, 3.12469940e+03,
#        2.89299692e+03, 2.73439223e+03, 2.62113622e+03, 2.52136031e+03,
#        2.40892635e+03, 2.27571838e+03, 2.13129927e+03, 1.99252338e+03,
#        1.80107530e+03, 1.67455212e+03, 1.56144125e+03, 1.42308240e+03,
#        1.29159185e+03, 1.19623972e+03, 1.11085375e+03, 1.01919700e+03,
#        9.42217346e+02, 8.77398614e+02, 8.13212908e+02, 7.57791021e+02,
#        5.30804848e+02, 3.95586660e+02, 2.98548193e+02, 2.13827537e+02,
#        1.38582368e+02, 8.11000982e+01, 4.43207826e+01, 2.31806499e+01,
#        1.16952771e+01, 5.70087210e+00, 2.69006889e+00, 1.23134959e+00,
#        5.48137067e-01, 2.38099650e-01, 1.01299805e-01, 4.23460681e-02,
#        1.74300369e-02, 7.08223923e-03, 2.84699934e-03, 1.13216050e-03,
#        4.46340278e-04, 1.74719947e-04, 6.78609133e-05, 2.61569981e-05]), array([5.09647513e-10, 3.76577929e-09, 2.78260188e-08, 2.05606929e-07,
#        1.51923929e-06, 1.12257226e-05, 8.29476744e-05, 6.12898462e-04,
#        4.52870091e-03, 7.46654779e-03, 1.23100582e-02, 2.02952805e-02,
#        3.34599496e-02, 5.51626861e-02, 9.09387279e-02, 1.49907801e-01,
#        2.47088015e-01, 4.07196133e-01, 6.70879340e-01, 1.10476089e+00,
#        1.81786807e+00, 2.98753781e+00, 4.89971111e+00, 8.00878976e+00,
#        1.30200243e+01, 2.09842718e+01, 3.33619715e+01, 5.19479637e+01,
#        7.84607095e+01, 1.13638421e+02, 1.56081059e+02, 1.96570884e+02,
#        2.32086275e+02, 2.61380288e+02, 2.84601381e+02, 3.02584480e+02,
#        3.16348313e+02, 3.26837194e+02, 3.34832785e+02, 3.40944421e+02,
#        3.45635835e+02, 3.49251208e+02, 3.52046917e+02, 3.54213465e+02,
#        3.55892710e+02, 3.57191617e+02, 3.58190345e+02, 3.58950048e+02,
#        3.59517587e+02, 3.59929105e+02, 3.60212869e+02, 3.60390890e+02,
#        3.60498261e+02, 3.60382690e+02, 3.60065993e+02, 3.59562911e+02,
#        3.58882156e+02, 3.58027428e+02, 3.56997988e+02, 3.55789243e+02,
#        3.54393189e+02, 3.52798994e+02, 3.50992663e+02, 3.48957983e+02,
#        3.32098589e+02, 3.02799156e+02, 2.57002219e+02, 1.96084931e+02,
#        1.31388364e+02, 7.83197448e+01, 4.32828761e+01, 2.28018995e+01,
#        1.15591048e+01, 5.65233912e+00, 2.67284488e+00, 1.22524379e+00,
#        5.45970905e-01, 2.37329969e-01, 1.01026015e-01, 4.22487737e-02,
#        1.73956508e-02, 7.07025434e-03, 2.84294158e-03, 1.13085850e-03,
#        4.45957446e-04, 1.74619994e-04, 6.78379972e-05, 2.61521582e-05]), array([3.18276680e+02, 5.15494764e+02, 8.34603417e+02, 1.34984148e+03,
#        2.17754404e+03, 3.49271719e+03, 5.53883339e+03, 8.59903396e+03,
#        1.28596985e+04, 1.41004051e+04, 1.53944194e+04, 1.67259835e+04,
#        1.80737535e+04, 1.94105284e+04, 2.07019732e+04, 2.19058316e+04,
#        2.29731701e+04, 2.38460188e+04, 2.44620579e+04, 2.47544267e+04,
#        2.46600235e+04, 2.41289034e+04, 2.31377446e+04, 2.17048011e+04,
#        1.99088113e+04, 1.78945164e+04, 1.60740234e+04, 1.42299539e+04,
#        1.26095764e+04, 1.15429484e+04, 1.06169501e+04, 9.65419817e+03,
#        8.61762313e+03, 7.45221254e+03, 6.37698068e+03, 5.54493699e+03,
#        4.98362223e+03, 4.62849076e+03, 4.37602692e+03, 4.12356552e+03,
#        3.81323634e+03, 3.45130275e+03, 3.08527838e+03, 2.77048593e+03,
#        2.53710421e+03, 2.37720062e+03, 2.26294587e+03, 2.16241026e+03,
#        2.04940876e+03, 1.91578927e+03, 1.77108640e+03, 1.63213249e+03,
#        1.44057704e+03, 1.31416943e+03, 1.20137526e+03, 1.06351949e+03,
#        9.32709691e+02, 8.38212293e+02, 7.53855766e+02, 6.63407753e+02,
#        5.87824157e+02, 5.24599621e+02, 4.62220246e+02, 4.08833038e+02,
#        1.98706259e+02, 9.27875040e+01, 4.15459743e+01, 1.77426057e+01,
#        7.19400399e+00, 2.78035345e+00, 1.03790652e+00, 3.78750361e-01,
#        1.36172284e-01, 4.85329744e-02, 1.72240103e-02, 6.10580003e-03,
#        2.16616118e-03, 7.69681029e-04, 2.73790633e-04, 9.72943726e-05,
#        3.43861519e-05, 1.19848862e-05, 4.05776064e-06, 1.30199894e-06,
#        3.82832011e-07, 9.99536287e-08, 2.29161021e-08, 4.83997390e-09]))

# %%
# Third-party imports
import numpy as np
import matplotlib.pyplot as plt
import camb
import hmcode

# Cosmology
h =  0.6736
Omega_c = 0.12/(h**2)
Omega_b =  0.02237/(h**2)
Omega_k = 0.0
ns = 0.9649
w0 = -1.
wa = 0.
sigma_8=0.8225143734912881
m_nu = 0.
norm_sigma8 = True
As = np.exp(3.044)/(10**10)           

# AGN-feedback temperature [K]
T_AGNs = np.power(10, np.array([7.6, 7.8, 8.0, 8.3]))

# CAMB
kmax_CAMB = 1.32405e+03

# Wavenumbers [h/Mpc]
k = [7.42280e-05, 1.22381e-04, 2.01773e-04, 3.32667e-04, 5.48475e-04, 9.04282e-04,
 1.49091e-03 ,2.45809e-03 ,4.05271e-03, 4.59233e-03, 5.20379e-03, 5.89666e-03,
 6.68179e-03, 7.57146e-03 ,8.57959e-03, 9.72195e-03, 1.10164e-02, 1.24832e-02,
 1.41454e-02, 1.60288e-02, 1.81630e-02, 2.05814e-02, 2.33218e-02, 2.64270e-02,
 2.99457e-02, 3.39330e-02, 3.84511e-02, 4.35708e-02, 4.93722e-02, 5.59460e-02,
 6.33951e-02, 7.08179e-02, 7.82407e-02, 8.56635e-02, 9.30863e-02, 1.00509e-01,
 1.07932e-01 ,1.15355e-01, 1.22778e-01, 1.30200e-01, 1.37623e-01, 1.45046e-01,
 1.52469e-01, 1.59892e-01, 1.67314e-01, 1.74737e-01, 1.82160e-01, 1.89583e-01,
 1.97006e-01, 2.04428e-01, 2.11851e-01, 2.19274e-01, 2.32559e-01, 2.46650e-01,
 2.61594e-01, 2.77443e-01, 2.94253e-01, 3.12081e-01, 3.30989e-01, 3.51043e-01,
 3.72313e-01, 3.94870e-01, 4.18795e-01, 4.44169e-01, 6.19887e-01, 8.65122e-01,
 1.20738e+00, 1.68503e+00, 2.35165e+00, 3.28199e+00, 4.58038e+00, 6.39244e+00,
 8.92136e+00 ,1.24508e+01, 1.73764e+01, 2.42508e+01, 3.38447e+01, 4.72341e+01,
 6.59205e+01, 9.19994e+01, 1.28396e+02, 1.79190e+02, 2.50080e+02, 3.49015e+02,
 4.87090e+02, 6.79789e+02, 9.48722e+02, 1.32405e+03]
k=np.array(k)

# Redshifts
zs = [1., 0.5, 0.25, 0.]
zs = np.array(zs)

# Halo masses [Msun/h] (for halo model only)

M = np.logspace(cosmos_LCDM['M_min'],cosmos_LCDM['M_max'], 100)

# Sets cosmological parameters in camb to calculate the linear power spectrum
pars = camb.CAMBparams(WantCls=False)
wb, wc = Omega_b*h**2, Omega_c*h**2

# This function sets standard and helium set using BBN consistency
pars.set_cosmology(ombh2=wb, omch2=wc, H0=100.*h, mnu=m_nu, omk=Omega_k)
pars.set_dark_energy(w=w0, wa=wa, dark_energy_model='ppf')
pars.InitPower.set_params(As=As, ns=ns, r=0.)
pars.set_matter_power(redshifts=zs, kmax=kmax_CAMB) # Setup the linear matter power spectrum
Omega_m = pars.omegam # Extract the matter density

# Scale 'As' to be correct for the desired 'sigma_8' value if necessary
if norm_sigma8:
    results = camb.get_results(pars)
    sigma_8_init = results.get_sigma8_0()
    print('Running CAMB')
    print('Initial sigma_8:', sigma_8_init)
    print('Desired sigma_8:', sigma_8)
    scaling = (sigma_8/sigma_8_init)**2
    As *= scaling
    pars.InitPower.set_params(As=As, ns=ns, r=0.)
# Run
results = camb.get_results(pars)
Pk_lin_interp = results.get_matter_power_interpolator(nonlinear=False).P
Pk_nonlin_interp = results.get_matter_power_interpolator(nonlinear=True).P
sigma_8 = results.get_sigma8_0()
print('Final sigma_8:', sigma_8)

# Arrays for CAMB non-linear spectrum
Pk_CAMB = np.zeros((len(zs), len(k)))
for iz, z in enumerate(zs):
    Pk_CAMB[iz, :] = Pk_nonlin_interp(z, k)

Rk_feedback = []
Pk_gravity = hmcode.power(k, zs, results, T_AGN=None, verbose=True,tweaks=False)

plt.xscale('log')
plt.yscale('log')

=
plt.plot(k, Pk_gravity[3],label='HMCODE2020')
plt.plot(power_spec_dic_LCDM['k'],PS_LCDM_matter_nonlin[2],label='axionHMCODE - 2 halo')
plt.plot(power_spec_dic_LCDM['k'],PS_LCDM_matter_nonlin[1],label='axionHMCODE - 1 halo')
#plt.plot(power_spec_dic_LCDM['k'],PS_LCDM_matter_nonlin[0],label='axionHMCODE - total')
plt.plot(power_spec_dic_LCDM['k'],PS_LCDM_matter_nonlin[1]+PS_LCDM_matter_nonlin[2],label='axionHMCODE - total')


plt.legend()
plt.savefig("full_spectra_comparison_one_two_halo.pdf")
# Out:
# Running CAMB
# Initial sigma_8: 0.8225458356297418
# Desired sigma_8: 0.8225143734912881
# Final sigma_8: 0.8225143734912883
# changes made!
# HMcode parameters
# Halo mass range: 10^0.0 -> 10^18.0 Msun/h
# Omega_m: 0.314
# Neutrino mass fraction: 0.00%
# Linear growth at z=0: 0.787
#
# Redshift: 1.0
# Scale factor: 0.5
# Omega_m(z): 0.785
# Un-normalisaed growth (= a for a << 1): 0.478
# Normalised growth (= 1 at z = 0): 0.607
# Accumulated growth (= a for a << 1): 0.494
# Linear collapse threshold: 1.684
# Virial halo overdensity: 195.3
# Lagrangian radius range: 0.00014 -> 140.0 Mpc/h
# RMS in matter field range: 7.758 -> 0.02536
# Peak height range: 0.2171 -> 66.41
# Non-linear Lagrangian radius: 0.7505 Mpc/h
# RMS in matter field at 8 Mpc/h: 0.4995
# RMS in matter displacement field: 3.594 Mpc/h
# Effective index at collapse scale: -2.239
#
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# Redshift: 0.5
# Scale factor: 0.667
# Omega_m(z): 0.607
# Un-normalisaed growth (= a for a << 1): 0.606
# Normalised growth (= 1 at z = 0): 0.769
# Accumulated growth (= a for a << 1): 0.65
# Linear collapse threshold: 1.682
# Virial halo overdensity: 219.3
# Lagrangian radius range: 0.00014 -> 140.0 Mpc/h
# RMS in matter field range: 9.802 -> 0.03213
# Peak height range: 0.1716 -> 52.35
# Non-linear Lagrangian radius: 1.346 Mpc/h
# RMS in matter field at 8 Mpc/h: 0.6329
# RMS in matter displacement field: 4.553 Mpc/h
# Effective index at collapse scale: -2.131
#
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# Redshift: 0.25
# Scale factor: 0.8
# Omega_m(z): 0.472
# Un-normalisaed growth (= a for a << 1): 0.689
# Normalised growth (= 1 at z = 0): 0.876
# Accumulated growth (= a for a << 1): 0.768
# Linear collapse threshold: 1.68
# Virial halo overdensity: 246.9
# Lagrangian radius range: 0.00014 -> 140.0 Mpc/h
# RMS in matter field range: 11.15 -> 0.03658
# Peak height range: 0.1507 -> 45.91
# Non-linear Lagrangian radius: 1.803 Mpc/h
# RMS in matter field at 8 Mpc/h: 0.7206
# RMS in matter displacement field: 5.184 Mpc/h
# Effective index at collapse scale: -2.067
#
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# Redshift: 0.0
# Scale factor: 1.0
# Omega_m(z): 0.314
# Un-normalisaed growth (= a for a << 1): 0.787
# Normalised growth (= 1 at z = 0): 1.0
# Accumulated growth (= a for a << 1): 0.933
# Linear collapse threshold: 1.676
# Virial halo overdensity: 301.4
# Lagrangian radius range: 0.00014 -> 140.0 Mpc/h
# RMS in matter field range: 12.71 -> 0.04177
# Peak height range: 0.1319 -> 40.12
# Non-linear Lagrangian radius: 2.386 Mpc/h
# RMS in matter field at 8 Mpc/h: 0.8227
# RMS in matter displacement field: 5.918 Mpc/h
# Effective index at collapse scale: -2.0
#
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# (88, 1)
# HMcode predictions complete for 4 redshifts
# Total HMcode run time: 0.210s
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 93
#      89 plt.yscale('log')
#      91 #plt.plot(k, Pk_gravity[3,:]/PS_LCDM_matter_nonlin[0])
# ---> 93 plt.plot(k, Pk_gravity[3],label='HMCODE2020')
#      94 plt.plot(power_spec_dic_LCDM['k'],PS_LCDM_matter_nonlin[2],label='axionHMCODE - 2 halo')
#      95 plt.plot(power_spec_dic_LCDM['k'],PS_LCDM_matter_nonlin[1],label='axionHMCODE - 1 halo')
#
# IndexError: tuple index out of range

# %%
plt.plot(power_spec_dic_LCDM['k'],(PS_LCDM_matter_nonlin[0])/Pk_gravity[3],label='axionHMCODE/HM2020 total')
#plt.plot(power_spec_dic_LCDM['k'],(PS_LCDM_matter_nonlin[1])/Pk_gravity[3],label='axionHMCODE 1-halo/HM2020 total')
#plt.plot(power_spec_dic_LCDM['k'],(PS_LCDM_matter_nonlin[2])/Pk_gravity[3],label='axionHMCODE 2-halo/HM2020 total')

plt.legend(fontsize=7)
plt.ylabel("Ratio")
plt.xlabel(r'k [h/Mpc]')  
plt.xscale('log')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.plot(power_spec_dic_LCDM['k'],(PS_LCDM_matter_nonlin[0])/Pk_gravity[3],label='axionHMCODE/HM2020 total')
#       2 #plt.plot(power_spec_dic_LCDM['k'],(PS_LCDM_matter_nonlin[1])/Pk_gravity[3],label='axionHMCODE 1-halo/HM2020 total')
#       3 #plt.plot(power_spec_dic_LCDM['k'],(PS_LCDM_matter_nonlin[2])/Pk_gravity[3],label='axionHMCODE 2-halo/HM2020 total')
#       5 plt.legend(fontsize=7)
#
# IndexError: tuple index out of range
